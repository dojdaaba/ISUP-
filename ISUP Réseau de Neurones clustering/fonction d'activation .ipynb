# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.arange(0,10,0.1)

# %%
y= np.sin(x)

# %%
plt.plot(x,y)

# %%
sigmoid = lambda x: 1 / (1 + np.exp(-x))
x=np.linspace(-10,10,100)
plt.plot(x,sigmoid(x),'b')
plt.grid()

#plt.title('Sigmoid Function')
#plt.suptitle('Sigmoid')

#plt.text(4,0.8,r'$f(x)=\frac{1}{1+e^{-x}}$',fontsize=15)
plt.savefig('sigplot.png')

print("-")
# Out:
# -

# %%
x=np.linspace(-10,10,100)
plt.plot(x,np.tanh(x),'b')
plt.grid()

#plt.title('Tangente Hyperbolique')


#plt.text(4,0.5,r'$f(x)=\frac{1-e^{-2x}}{1+e^{-2x}}$',fontsize=15)
plt.savefig('tangtplot.png')

print("-")
# Out:
# -

# %%
import numpy as np
import matplotlib.pyplot as plt

x= np.linspace(-1.5, 1.5, 100)
def linear_step_func(x,k,s):
    y= np.piecewise(x, [x <= -s,(x > -s) & (x < s), x >= s],[0.,lambda x: k*x+0.5 ,  1.])
    return y
plt.grid()
plt.plot(x, linear_step_func(x,0.7, 0.7))
plt.plot(0.7,linear_step_func(0.7,0.7, 0.7),'ko')
plt.plot(-0.7,linear_step_func(-0.7,0.7, 0.7),'ko')
plt.text(-0.95,0.05,r'$-S$',fontsize=15)
plt.text(0.7,0.9,r'$S$',fontsize=15)
plt.savefig('LinéaireSeuilléeplot.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

z = np.arange(-2, 2, .1)
zero = np.zeros(len(z))
y = np.max([zero, z], axis=0)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(z, y)
ax.set_ylim([-2.0, 2.0])
ax.set_xlim([-2.0, 2.0])
ax.grid(True)
ax.set_xlabel('z')
plt.savefig('reluplot.png')

plt.show()

# %%
"""Softmax."""

scores = [3.0, 1.0, 0.2]

import numpy as np

def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    exp_x = np.exp(x)
    return exp_x / exp_x.sum(axis=0)

print(softmax(scores))

# Plot softmax curves
import matplotlib.pyplot as plt
x = np.arange(-2.0, 6.0, 0.1)
scores = np.vstack([x, np.ones_like(x), 0.2 * np.ones_like(x)])

plt.plot(x, softmax(scores).T, linewidth=2)
plt.savefig('Softmax.png')
plt.show()
# Out:
# [0.8360188  0.11314284 0.05083836]

# %%
def f(x,S):
    if(x<S):
        return 0
    else: 
        return 1

def linear_step_func(x,s):
    y= np.piecewise(x, [x < s, x >= s],[0.,  1.])
    return y

# %%
x=np.linspace(-1,1,100)
plt.plot(x,linear_step_func(x,0.5),'b')
plt.text(0.5,-0.001,r'$S$',fontsize=15)

plt.savefig('pasplot.png')

print("-")
# Out:
# -
